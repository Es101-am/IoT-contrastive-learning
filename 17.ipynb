# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import random
import numpy as np

# Set random seed
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False



# Step 1: Updated dataset using new generate_sample logic (from previous discussion)
class PairedSensorDataset(Dataset):
    def __init__(self, num_samples=10000):
        self.raw_data = [self.generate_sample(i) for i in range(num_samples)]
        self._compute_normalization_stats()
        self.data = [self._normalize(sample) for sample in self.raw_data]

    def generate_sample(self, pair_id):
        house_id = random.randint(0, 9)
        occupancy = random.choice([0, 1])
        time_of_day = random.choice(['morning', 'afternoon', 'evening', 'night'])

        if time_of_day == 'morning':
            set_temp = 21.0
        elif time_of_day == 'afternoon':
            set_temp = 22.5
        elif time_of_day == 'evening':
            set_temp = 23.0
        else:
            set_temp = 20.0

        actual_temp = random.uniform(18.0, 26.0)
        humidity = random.uniform(30.0, 70.0)
        comfort_gap = set_temp - actual_temp
        humidity_factor = (humidity - 50) / 100
        occ_factor = 0.4 if occupancy else 0.1

        hvac = max(0.0, comfort_gap * occ_factor + humidity_factor)
        hvac = min(hvac, 2.5)
        base_power = 0.3 + 0.2 * occupancy + 0.4 * hvac + house_id * 0.05
        power = base_power + random.uniform(0.0, 0.2)

        # Add normalized pair_id as a shared signal between agent1 and agent2
        pair_token = pair_id / 10000.0

        agent1_obs = [set_temp, actual_temp, humidity, pair_token]
        agent2_obs = [power, hvac, house_id / 10.0, occupancy, pair_token]

        return {"agent1_obs": agent1_obs, "agent2_obs": agent2_obs}

    def _compute_normalization_stats(self):
        import numpy as np
        x1_list = [sample["agent1_obs"] for sample in self.raw_data]
        x2_list = [sample["agent2_obs"] for sample in self.raw_data]
        self.x1_min = torch.tensor(np.min(x1_list, axis=0), dtype=torch.float32)
        self.x1_max = torch.tensor(np.max(x1_list, axis=0), dtype=torch.float32)
        self.x2_min = torch.tensor(np.min(x2_list, axis=0), dtype=torch.float32)
        self.x2_max = torch.tensor(np.max(x2_list, axis=0), dtype=torch.float32)

    def _normalize(self, sample):
        x1 = torch.tensor(sample["agent1_obs"], dtype=torch.float32)
        x2 = torch.tensor(sample["agent2_obs"], dtype=torch.float32)
        x1_norm = (x1 - self.x1_min) / (self.x1_max - self.x1_min + 1e-8)
        x2_norm = (x2 - self.x2_min) / (self.x2_max - self.x2_min + 1e-8)
        return {"agent1_obs": x1_norm, "agent2_obs": x2_norm}

    def __getitem__(self, idx):
        sample = self.data[idx]
        return sample["agent1_obs"], sample["agent2_obs"]

    def __len__(self):
        return len(self.data)

# Step 2: Encoders + Projection Head + Cosine Similarity
class AgentEncoder(nn.Module):
    def __init__(self, input_dim, output_dim=128):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU()
        )
        self.projector = nn.Sequential(
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, output_dim)
        )

    def forward(self, x):
        features = self.encoder(x)
        projected = self.projector(features)
        return F.normalize(projected, dim=-1)  # L2 norm for cosine similarity
    
# Step 3: Contrastive training with cosine similarity
def train_contrastive():
    dataset = PairedSensorDataset()
    loader = DataLoader(dataset, batch_size=128, shuffle=True)

    encoder1 = AgentEncoder(input_dim=4)
    encoder2 = AgentEncoder(input_dim=5)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    encoder1.to(device)
    encoder2.to(device)

    optimizer = torch.optim.Adam(list(encoder1.parameters()) + list(encoder2.parameters()), lr=1e-4)

    initial_temperature = 0.2  # Start soft
    min_temperature = 0.01
    decay_rate = 0.99

    for epoch in range(1, 501):
        encoder1.train()
        encoder2.train()
        total_loss, total_acc = 0.0, 0.0

        # Update temperature (annealing)
        temperature = max(min_temperature, initial_temperature * (decay_rate ** epoch))

        for x1, x2 in loader:
            x1, x2 = x1.to(device), x2.to(device)
            z1 = encoder1(x1)
            z2 = encoder2(x2)

            sim_matrix = torch.matmul(z1, z2.T) / temperature

            labels = torch.arange(sim_matrix.size(0)).to(sim_matrix.device)

            loss_i = F.cross_entropy(sim_matrix, labels)
            loss_t = F.cross_entropy(sim_matrix.T, labels)
            loss = (loss_i + loss_t) / 2

            preds_i = sim_matrix.argmax(dim=1)
            preds_t = sim_matrix.T.argmax(dim=1)
            acc_i = (preds_i == labels).float().mean()
            acc_t = (preds_t == labels).float().mean()
            accuracy = (acc_i + acc_t) / 2

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            total_acc += accuracy.item()

        avg_loss = total_loss / len(loader)
        avg_acc = total_acc / len(loader)
        print(f"Epoch {epoch:3d} | Temp: {temperature:.4f} | Loss: {avg_loss:.4f} | Accuracy: {avg_acc:.4f}")

# Run training
train_contrastive()
# Out:
# Epoch   1 | Temp: 0.1980 | Loss: 4.7427 | Accuracy: 0.0222
# Epoch   2 | Temp: 0.1960 | Loss: 3.9335 | Accuracy: 0.0673
# Epoch   3 | Temp: 0.1941 | Loss: 3.3859 | Accuracy: 0.1346
# Epoch   4 | Temp: 0.1921 | Loss: 3.2618 | Accuracy: 0.1813
# Epoch   5 | Temp: 0.1902 | Loss: 3.1701 | Accuracy: 0.2338
# Epoch   6 | Temp: 0.1883 | Loss: 3.0725 | Accuracy: 0.2761
# Epoch   7 | Temp: 0.1864 | Loss: 2.9669 | Accuracy: 0.3023
# Epoch   8 | Temp: 0.1845 | Loss: 2.8766 | Accuracy: 0.3194
# Epoch   9 | Temp: 0.1827 | Loss: 2.8219 | Accuracy: 0.3482
# Epoch  10 | Temp: 0.1809 | Loss: 2.7781 | Accuracy: 0.3800
# Epoch  11 | Temp: 0.1791 | Loss: 2.7480 | Accuracy: 0.4024
# Epoch  12 | Temp: 0.1773 | Loss: 2.7202 | Accuracy: 0.4144
# Epoch  13 | Temp: 0.1755 | Loss: 2.6967 | Accuracy: 0.4294
# Epoch  14 | Temp: 0.1737 | Loss: 2.6714 | Accuracy: 0.4392
# Epoch  15 | Temp: 0.1720 | Loss: 2.6532 | Accuracy: 0.4414
# Epoch  16 | Temp: 0.1703 | Loss: 2.6296 | Accuracy: 0.4472
# Epoch  17 | Temp: 0.1686 | Loss: 2.6066 | Accuracy: 0.4494
# Epoch  18 | Temp: 0.1669 | Loss: 2.5742 | Accuracy: 0.4576
# Epoch  19 | Temp: 0.1652 | Loss: 2.5357 | Accuracy: 0.4559
# Epoch  20 | Temp: 0.1636 | Loss: 2.4879 | Accuracy: 0.4371
# Epoch  21 | Temp: 0.1619 | Loss: 2.4339 | Accuracy: 0.4279
# Epoch  22 | Temp: 0.1603 | Loss: 2.3797 | Accuracy: 0.4233
# Epoch  23 | Temp: 0.1587 | Loss: 2.3299 | Accuracy: 0.4343
# Epoch  24 | Temp: 0.1571 | Loss: 2.2927 | Accuracy: 0.4371
# Epoch  25 | Temp: 0.1556 | Loss: 2.2607 | Accuracy: 0.4532
# Epoch  26 | Temp: 0.1540 | Loss: 2.2376 | Accuracy: 0.4520
# Epoch  27 | Temp: 0.1525 | Loss: 2.2121 | Accuracy: 0.4542
# Epoch  28 | Temp: 0.1509 | Loss: 2.1900 | Accuracy: 0.4619
# Epoch  29 | Temp: 0.1494 | Loss: 2.1740 | Accuracy: 0.4669
# Epoch  30 | Temp: 0.1479 | Loss: 2.1499 | Accuracy: 0.4722
# Epoch  31 | Temp: 0.1465 | Loss: 2.1262 | Accuracy: 0.4796
# Epoch  32 | Temp: 0.1450 | Loss: 2.1125 | Accuracy: 0.4837
# Epoch  33 | Temp: 0.1435 | Loss: 2.0925 | Accuracy: 0.4851
# Epoch  34 | Temp: 0.1421 | Loss: 2.0611 | Accuracy: 0.4938
# Epoch  35 | Temp: 0.1407 | Loss: 2.0519 | Accuracy: 0.4941
# Epoch  36 | Temp: 0.1393 | Loss: 2.0320 | Accuracy: 0.4945
# Epoch  37 | Temp: 0.1379 | Loss: 2.0094 | Accuracy: 0.4967
# Epoch  38 | Temp: 0.1365 | Loss: 1.9768 | Accuracy: 0.5109
# Epoch  39 | Temp: 0.1351 | Loss: 1.9586 | Accuracy: 0.5125
# Epoch  40 | Temp: 0.1338 | Loss: 1.9404 | Accuracy: 0.5135
# Epoch  41 | Temp: 0.1325 | Loss: 1.9222 | Accuracy: 0.5197
# Epoch  42 | Temp: 0.1311 | Loss: 1.9010 | Accuracy: 0.5186
# Epoch  43 | Temp: 0.1298 | Loss: 1.8944 | Accuracy: 0.5065
# Epoch  44 | Temp: 0.1285 | Loss: 1.8700 | Accuracy: 0.5214
# Epoch  45 | Temp: 0.1272 | Loss: 1.8540 | Accuracy: 0.5258
# Epoch  46 | Temp: 0.1260 | Loss: 1.8327 | Accuracy: 0.5368
# Epoch  47 | Temp: 0.1247 | Loss: 1.8157 | Accuracy: 0.5388
# Epoch  48 | Temp: 0.1235 | Loss: 1.8058 | Accuracy: 0.5357
# Epoch  49 | Temp: 0.1222 | Loss: 1.7877 | Accuracy: 0.5354
# Epoch  50 | Temp: 0.1210 | Loss: 1.7679 | Accuracy: 0.5428
# Epoch  51 | Temp: 0.1198 | Loss: 1.7627 | Accuracy: 0.5424
# Epoch  52 | Temp: 0.1186 | Loss: 1.7531 | Accuracy: 0.5425
# Epoch  53 | Temp: 0.1174 | Loss: 1.7321 | Accuracy: 0.5440
# Epoch  54 | Temp: 0.1162 | Loss: 1.7142 | Accuracy: 0.5550
# Epoch  55 | Temp: 0.1151 | Loss: 1.7068 | Accuracy: 0.5509
# Epoch  56 | Temp: 0.1139 | Loss: 1.6900 | Accuracy: 0.5563
# Epoch  57 | Temp: 0.1128 | Loss: 1.6796 | Accuracy: 0.5532
# Epoch  58 | Temp: 0.1117 | Loss: 1.6629 | Accuracy: 0.5643
# Epoch  59 | Temp: 0.1105 | Loss: 1.6589 | Accuracy: 0.5541
# Epoch  60 | Temp: 0.1094 | Loss: 1.6432 | Accuracy: 0.5657
# Epoch  61 | Temp: 0.1083 | Loss: 1.6274 | Accuracy: 0.5692
# Epoch  62 | Temp: 0.1073 | Loss: 1.6071 | Accuracy: 0.5743
# Epoch  63 | Temp: 0.1062 | Loss: 1.6025 | Accuracy: 0.5746
# Epoch  64 | Temp: 0.1051 | Loss: 1.5928 | Accuracy: 0.5663
# Epoch  65 | Temp: 0.1041 | Loss: 1.5836 | Accuracy: 0.5701
# Epoch  66 | Temp: 0.1030 | Loss: 1.5720 | Accuracy: 0.5683
# Epoch  67 | Temp: 0.1020 | Loss: 1.5510 | Accuracy: 0.5800
# Epoch  68 | Temp: 0.1010 | Loss: 1.5428 | Accuracy: 0.5799
# Epoch  69 | Temp: 0.1000 | Loss: 1.5349 | Accuracy: 0.5736
# Epoch  70 | Temp: 0.0990 | Loss: 1.5282 | Accuracy: 0.5688
# Epoch  71 | Temp: 0.0980 | Loss: 1.5110 | Accuracy: 0.5772
# Epoch  72 | Temp: 0.0970 | Loss: 1.5053 | Accuracy: 0.5753
# Epoch  73 | Temp: 0.0960 | Loss: 1.4846 | Accuracy: 0.5841
# Epoch  74 | Temp: 0.0951 | Loss: 1.4784 | Accuracy: 0.5789
# Epoch  75 | Temp: 0.0941 | Loss: 1.4733 | Accuracy: 0.5758
# Epoch  76 | Temp: 0.0932 | Loss: 1.4599 | Accuracy: 0.5833
# Epoch  77 | Temp: 0.0922 | Loss: 1.4465 | Accuracy: 0.5879
# Epoch  78 | Temp: 0.0913 | Loss: 1.4308 | Accuracy: 0.5967
# Epoch  79 | Temp: 0.0904 | Loss: 1.4288 | Accuracy: 0.5894
# Epoch  80 | Temp: 0.0895 | Loss: 1.4207 | Accuracy: 0.5862
# Epoch  81 | Temp: 0.0886 | Loss: 1.4153 | Accuracy: 0.5905
# Epoch  82 | Temp: 0.0877 | Loss: 1.4079 | Accuracy: 0.5855
# Epoch  83 | Temp: 0.0868 | Loss: 1.3873 | Accuracy: 0.5993
# Epoch  84 | Temp: 0.0860 | Loss: 1.3869 | Accuracy: 0.5967
# Epoch  85 | Temp: 0.0851 | Loss: 1.3778 | Accuracy: 0.5934
# Epoch  86 | Temp: 0.0843 | Loss: 1.3723 | Accuracy: 0.5921
# Epoch  87 | Temp: 0.0834 | Loss: 1.3567 | Accuracy: 0.5987
# Epoch  88 | Temp: 0.0826 | Loss: 1.3539 | Accuracy: 0.5991
# Epoch  89 | Temp: 0.0818 | Loss: 1.3432 | Accuracy: 0.5968
# Epoch  90 | Temp: 0.0809 | Loss: 1.3268 | Accuracy: 0.6060
# Epoch  91 | Temp: 0.0801 | Loss: 1.3306 | Accuracy: 0.6066
# Epoch  92 | Temp: 0.0793 | Loss: 1.3197 | Accuracy: 0.5992
# Epoch  93 | Temp: 0.0785 | Loss: 1.3220 | Accuracy: 0.5987
# Epoch  94 | Temp: 0.0778 | Loss: 1.3007 | Accuracy: 0.6060
# Epoch  95 | Temp: 0.0770 | Loss: 1.2895 | Accuracy: 0.6137
# Epoch  96 | Temp: 0.0762 | Loss: 1.2848 | Accuracy: 0.6123
# Epoch  97 | Temp: 0.0754 | Loss: 1.2790 | Accuracy: 0.6180
# Epoch  98 | Temp: 0.0747 | Loss: 1.2747 | Accuracy: 0.6129
# Epoch  99 | Temp: 0.0739 | Loss: 1.2619 | Accuracy: 0.6220
# Epoch 100 | Temp: 0.0732 | Loss: 1.2642 | Accuracy: 0.6072
# Epoch 101 | Temp: 0.0725 | Loss: 1.2540 | Accuracy: 0.6102
# Epoch 102 | Temp: 0.0717 | Loss: 1.2453 | Accuracy: 0.6121
# Epoch 103 | Temp: 0.0710 | Loss: 1.2366 | Accuracy: 0.6168
# Epoch 104 | Temp: 0.0703 | Loss: 1.2313 | Accuracy: 0.6167
# Epoch 105 | Temp: 0.0696 | Loss: 1.2245 | Accuracy: 0.6186
# Epoch 106 | Temp: 0.0689 | Loss: 1.2193 | Accuracy: 0.6212
# Epoch 107 | Temp: 0.0682 | Loss: 1.2161 | Accuracy: 0.6155
# Epoch 108 | Temp: 0.0676 | Loss: 1.2076 | Accuracy: 0.6193
# Epoch 109 | Temp: 0.0669 | Loss: 1.1896 | Accuracy: 0.6320
# Epoch 110 | Temp: 0.0662 | Loss: 1.1819 | Accuracy: 0.6326
# Epoch 111 | Temp: 0.0655 | Loss: 1.1889 | Accuracy: 0.6297
# Epoch 112 | Temp: 0.0649 | Loss: 1.1676 | Accuracy: 0.6381
# Epoch 113 | Temp: 0.0642 | Loss: 1.1743 | Accuracy: 0.6270
# Epoch 114 | Temp: 0.0636 | Loss: 1.1595 | Accuracy: 0.6364
# Epoch 115 | Temp: 0.0630 | Loss: 1.1599 | Accuracy: 0.6322
# Epoch 116 | Temp: 0.0623 | Loss: 1.1451 | Accuracy: 0.6397
# Epoch 117 | Temp: 0.0617 | Loss: 1.1439 | Accuracy: 0.6346
# Epoch 118 | Temp: 0.0611 | Loss: 1.1382 | Accuracy: 0.6339
# Epoch 119 | Temp: 0.0605 | Loss: 1.1315 | Accuracy: 0.6373
# Epoch 120 | Temp: 0.0599 | Loss: 1.1270 | Accuracy: 0.6336
# Epoch 121 | Temp: 0.0593 | Loss: 1.1262 | Accuracy: 0.6354
# Epoch 122 | Temp: 0.0587 | Loss: 1.1153 | Accuracy: 0.6449
# Epoch 123 | Temp: 0.0581 | Loss: 1.1146 | Accuracy: 0.6394
# Epoch 124 | Temp: 0.0575 | Loss: 1.0996 | Accuracy: 0.6467
# Epoch 125 | Temp: 0.0569 | Loss: 1.0938 | Accuracy: 0.6492
# Epoch 126 | Temp: 0.0564 | Loss: 1.0909 | Accuracy: 0.6521
# Epoch 127 | Temp: 0.0558 | Loss: 1.0839 | Accuracy: 0.6478
# Epoch 128 | Temp: 0.0553 | Loss: 1.0897 | Accuracy: 0.6363
# Epoch 129 | Temp: 0.0547 | Loss: 1.0824 | Accuracy: 0.6379
# Epoch 130 | Temp: 0.0542 | Loss: 1.0806 | Accuracy: 0.6415
# Epoch 131 | Temp: 0.0536 | Loss: 1.0634 | Accuracy: 0.6573
# Epoch 132 | Temp: 0.0531 | Loss: 1.0498 | Accuracy: 0.6659
# Epoch 133 | Temp: 0.0525 | Loss: 1.0454 | Accuracy: 0.6617
# Epoch 134 | Temp: 0.0520 | Loss: 1.0434 | Accuracy: 0.6563
# Epoch 135 | Temp: 0.0515 | Loss: 1.0516 | Accuracy: 0.6447
# Epoch 136 | Temp: 0.0510 | Loss: 1.0417 | Accuracy: 0.6523
# Epoch 137 | Temp: 0.0505 | Loss: 1.0321 | Accuracy: 0.6557
# Epoch 138 | Temp: 0.0500 | Loss: 1.0127 | Accuracy: 0.6689
# Epoch 139 | Temp: 0.0495 | Loss: 1.0183 | Accuracy: 0.6652
# Epoch 140 | Temp: 0.0490 | Loss: 1.0171 | Accuracy: 0.6554
# Epoch 141 | Temp: 0.0485 | Loss: 1.0060 | Accuracy: 0.6685
# Epoch 142 | Temp: 0.0480 | Loss: 1.0105 | Accuracy: 0.6598
# Epoch 143 | Temp: 0.0475 | Loss: 1.0049 | Accuracy: 0.6646
# Epoch 144 | Temp: 0.0470 | Loss: 0.9942 | Accuracy: 0.6659
# Epoch 145 | Temp: 0.0466 | Loss: 1.0113 | Accuracy: 0.6470
# Epoch 146 | Temp: 0.0461 | Loss: 0.9912 | Accuracy: 0.6671
# Epoch 147 | Temp: 0.0456 | Loss: 0.9894 | Accuracy: 0.6611
# Epoch 148 | Temp: 0.0452 | Loss: 0.9863 | Accuracy: 0.6622
# Epoch 149 | Temp: 0.0447 | Loss: 0.9762 | Accuracy: 0.6699
# Epoch 150 | Temp: 0.0443 | Loss: 0.9610 | Accuracy: 0.6780
# Epoch 151 | Temp: 0.0438 | Loss: 0.9674 | Accuracy: 0.6742
# Epoch 152 | Temp: 0.0434 | Loss: 0.9683 | Accuracy: 0.6626
# Epoch 153 | Temp: 0.0430 | Loss: 0.9501 | Accuracy: 0.6780
# Epoch 154 | Temp: 0.0425 | Loss: 0.9466 | Accuracy: 0.6800
# Epoch 155 | Temp: 0.0421 | Loss: 0.9295 | Accuracy: 0.6863
# Epoch 156 | Temp: 0.0417 | Loss: 0.9399 | Accuracy: 0.6779
# Epoch 157 | Temp: 0.0413 | Loss: 0.9277 | Accuracy: 0.6794
# Epoch 158 | Temp: 0.0409 | Loss: 0.9301 | Accuracy: 0.6745
# Epoch 159 | Temp: 0.0405 | Loss: 0.9300 | Accuracy: 0.6804
# Epoch 160 | Temp: 0.0401 | Loss: 0.9215 | Accuracy: 0.6809
# Epoch 161 | Temp: 0.0397 | Loss: 0.9244 | Accuracy: 0.6744
# Epoch 162 | Temp: 0.0393 | Loss: 0.9134 | Accuracy: 0.6816
# Epoch 163 | Temp: 0.0389 | Loss: 0.9219 | Accuracy: 0.6744
# Epoch 164 | Temp: 0.0385 | Loss: 0.9131 | Accuracy: 0.6813
# Epoch 165 | Temp: 0.0381 | Loss: 0.9012 | Accuracy: 0.6832
# Epoch 166 | Temp: 0.0377 | Loss: 0.8901 | Accuracy: 0.6935
# Epoch 167 | Temp: 0.0373 | Loss: 0.8980 | Accuracy: 0.6731
# Epoch 168 | Temp: 0.0370 | Loss: 0.9005 | Accuracy: 0.6793
# Epoch 169 | Temp: 0.0366 | Loss: 0.8845 | Accuracy: 0.6868
# Epoch 170 | Temp: 0.0362 | Loss: 0.8831 | Accuracy: 0.6902
# Epoch 171 | Temp: 0.0359 | Loss: 0.8732 | Accuracy: 0.6940
# Epoch 172 | Temp: 0.0355 | Loss: 0.8688 | Accuracy: 0.6918
# Epoch 173 | Temp: 0.0351 | Loss: 0.8692 | Accuracy: 0.6921
# Epoch 174 | Temp: 0.0348 | Loss: 0.8688 | Accuracy: 0.6831
# Epoch 175 | Temp: 0.0344 | Loss: 0.8672 | Accuracy: 0.6845
# Epoch 176 | Temp: 0.0341 | Loss: 0.8426 | Accuracy: 0.7024
# Epoch 177 | Temp: 0.0338 | Loss: 0.8556 | Accuracy: 0.6938
# Epoch 178 | Temp: 0.0334 | Loss: 0.8483 | Accuracy: 0.7008
# Epoch 179 | Temp: 0.0331 | Loss: 0.8396 | Accuracy: 0.7021
# Epoch 180 | Temp: 0.0328 | Loss: 0.8532 | Accuracy: 0.6869
# Epoch 181 | Temp: 0.0324 | Loss: 0.8314 | Accuracy: 0.7002
# Epoch 182 | Temp: 0.0321 | Loss: 0.8258 | Accuracy: 0.7052
# Epoch 183 | Temp: 0.0318 | Loss: 0.8348 | Accuracy: 0.6945
# Epoch 184 | Temp: 0.0315 | Loss: 0.8225 | Accuracy: 0.7077
# Epoch 185 | Temp: 0.0312 | Loss: 0.8229 | Accuracy: 0.6962
# Epoch 186 | Temp: 0.0308 | Loss: 0.8268 | Accuracy: 0.6957
# Epoch 187 | Temp: 0.0305 | Loss: 0.8071 | Accuracy: 0.7103
# Epoch 188 | Temp: 0.0302 | Loss: 0.8147 | Accuracy: 0.7045
# Epoch 189 | Temp: 0.0299 | Loss: 0.7960 | Accuracy: 0.7131
# Epoch 190 | Temp: 0.0296 | Loss: 0.8263 | Accuracy: 0.6947
# Epoch 191 | Temp: 0.0293 | Loss: 0.8207 | Accuracy: 0.6901
# Epoch 192 | Temp: 0.0290 | Loss: 0.8046 | Accuracy: 0.7021
# Epoch 193 | Temp: 0.0287 | Loss: 0.7955 | Accuracy: 0.7132
# Epoch 194 | Temp: 0.0285 | Loss: 0.7889 | Accuracy: 0.7143
# Epoch 195 | Temp: 0.0282 | Loss: 0.7901 | Accuracy: 0.7049
# Epoch 196 | Temp: 0.0279 | Loss: 0.7837 | Accuracy: 0.7103
# Epoch 197 | Temp: 0.0276 | Loss: 0.7803 | Accuracy: 0.7130
# Epoch 198 | Temp: 0.0273 | Loss: 0.7792 | Accuracy: 0.7127
# Epoch 199 | Temp: 0.0271 | Loss: 0.7778 | Accuracy: 0.7133
# Epoch 200 | Temp: 0.0268 | Loss: 0.7741 | Accuracy: 0.7112
# Epoch 201 | Temp: 0.0265 | Loss: 0.7665 | Accuracy: 0.7097
# Epoch 202 | Temp: 0.0263 | Loss: 0.7631 | Accuracy: 0.7192
# Epoch 203 | Temp: 0.0260 | Loss: 0.7611 | Accuracy: 0.7123
# Epoch 204 | Temp: 0.0257 | Loss: 0.7760 | Accuracy: 0.7054
# Epoch 205 | Temp: 0.0255 | Loss: 0.7608 | Accuracy: 0.7153
# Epoch 206 | Temp: 0.0252 | Loss: 0.7617 | Accuracy: 0.7119
# Epoch 207 | Temp: 0.0250 | Loss: 0.7533 | Accuracy: 0.7136
# Epoch 208 | Temp: 0.0247 | Loss: 0.7461 | Accuracy: 0.7191
# Epoch 209 | Temp: 0.0245 | Loss: 0.7460 | Accuracy: 0.7169
# Epoch 210 | Temp: 0.0242 | Loss: 0.7426 | Accuracy: 0.7209
# Epoch 211 | Temp: 0.0240 | Loss: 0.7340 | Accuracy: 0.7212
# Epoch 212 | Temp: 0.0238 | Loss: 0.7359 | Accuracy: 0.7179
# Epoch 213 | Temp: 0.0235 | Loss: 0.7262 | Accuracy: 0.7279
# Epoch 214 | Temp: 0.0233 | Loss: 0.7378 | Accuracy: 0.7161
# Epoch 215 | Temp: 0.0230 | Loss: 0.7372 | Accuracy: 0.7173
# Epoch 216 | Temp: 0.0228 | Loss: 0.7367 | Accuracy: 0.7147
# Epoch 217 | Temp: 0.0226 | Loss: 0.7268 | Accuracy: 0.7256
# Epoch 218 | Temp: 0.0224 | Loss: 0.7419 | Accuracy: 0.7086
# Epoch 219 | Temp: 0.0221 | Loss: 0.7164 | Accuracy: 0.7275
# Epoch 220 | Temp: 0.0219 | Loss: 0.7127 | Accuracy: 0.7298
# Epoch 221 | Temp: 0.0217 | Loss: 0.7066 | Accuracy: 0.7358
# Epoch 222 | Temp: 0.0215 | Loss: 0.6933 | Accuracy: 0.7433
# Epoch 223 | Temp: 0.0213 | Loss: 0.7064 | Accuracy: 0.7255
# Epoch 224 | Temp: 0.0211 | Loss: 0.6946 | Accuracy: 0.7366
# Epoch 225 | Temp: 0.0208 | Loss: 0.6933 | Accuracy: 0.7341
# Epoch 226 | Temp: 0.0206 | Loss: 0.6935 | Accuracy: 0.7339
# Epoch 227 | Temp: 0.0204 | Loss: 0.6929 | Accuracy: 0.7305
# Epoch 228 | Temp: 0.0202 | Loss: 0.6981 | Accuracy: 0.7249
# Epoch 229 | Temp: 0.0200 | Loss: 0.6982 | Accuracy: 0.7270
# Epoch 230 | Temp: 0.0198 | Loss: 0.6785 | Accuracy: 0.7387
# Epoch 231 | Temp: 0.0196 | Loss: 0.6965 | Accuracy: 0.7229
# Epoch 232 | Temp: 0.0194 | Loss: 0.6682 | Accuracy: 0.7418
# Epoch 233 | Temp: 0.0192 | Loss: 0.6744 | Accuracy: 0.7401
# Epoch 234 | Temp: 0.0190 | Loss: 0.6964 | Accuracy: 0.7236
# Epoch 235 | Temp: 0.0188 | Loss: 0.6630 | Accuracy: 0.7440
# Epoch 236 | Temp: 0.0187 | Loss: 0.6677 | Accuracy: 0.7380
# Epoch 237 | Temp: 0.0185 | Loss: 0.6654 | Accuracy: 0.7423
# Epoch 238 | Temp: 0.0183 | Loss: 0.6706 | Accuracy: 0.7321
# Epoch 239 | Temp: 0.0181 | Loss: 0.6640 | Accuracy: 0.7395
# Epoch 240 | Temp: 0.0179 | Loss: 0.6687 | Accuracy: 0.7334
# Epoch 241 | Temp: 0.0177 | Loss: 0.6545 | Accuracy: 0.7428
# Epoch 242 | Temp: 0.0176 | Loss: 0.6465 | Accuracy: 0.7493
# Epoch 243 | Temp: 0.0174 | Loss: 0.6414 | Accuracy: 0.7536
# Epoch 244 | Temp: 0.0172 | Loss: 0.6621 | Accuracy: 0.7341
# Epoch 245 | Temp: 0.0170 | Loss: 0.6291 | Accuracy: 0.7583
# Epoch 246 | Temp: 0.0169 | Loss: 0.6536 | Accuracy: 0.7362
# Epoch 247 | Temp: 0.0167 | Loss: 0.6359 | Accuracy: 0.7507
# Epoch 248 | Temp: 0.0165 | Loss: 0.6663 | Accuracy: 0.7299
# Epoch 249 | Temp: 0.0164 | Loss: 0.6398 | Accuracy: 0.7457
# Epoch 250 | Temp: 0.0162 | Loss: 0.6413 | Accuracy: 0.7431
# Epoch 251 | Temp: 0.0160 | Loss: 0.6332 | Accuracy: 0.7462
# Epoch 252 | Temp: 0.0159 | Loss: 0.6311 | Accuracy: 0.7463
# Epoch 253 | Temp: 0.0157 | Loss: 0.6434 | Accuracy: 0.7382
# Epoch 254 | Temp: 0.0156 | Loss: 0.6219 | Accuracy: 0.7495
# Epoch 255 | Temp: 0.0154 | Loss: 0.6215 | Accuracy: 0.7515
# Epoch 256 | Temp: 0.0153 | Loss: 0.6189 | Accuracy: 0.7550
# Epoch 257 | Temp: 0.0151 | Loss: 0.6270 | Accuracy: 0.7534
# Epoch 258 | Temp: 0.0150 | Loss: 0.6239 | Accuracy: 0.7488
# Epoch 259 | Temp: 0.0148 | Loss: 0.6291 | Accuracy: 0.7419
# Epoch 260 | Temp: 0.0147 | Loss: 0.6084 | Accuracy: 0.7566
# Epoch 261 | Temp: 0.0145 | Loss: 0.6034 | Accuracy: 0.7582
# Epoch 262 | Temp: 0.0144 | Loss: 0.6031 | Accuracy: 0.7602
# Epoch 263 | Temp: 0.0142 | Loss: 0.6138 | Accuracy: 0.7510
# Epoch 264 | Temp: 0.0141 | Loss: 0.6152 | Accuracy: 0.7455
# Epoch 265 | Temp: 0.0139 | Loss: 0.6084 | Accuracy: 0.7501
# Epoch 266 | Temp: 0.0138 | Loss: 0.6040 | Accuracy: 0.7557
# Epoch 267 | Temp: 0.0137 | Loss: 0.5903 | Accuracy: 0.7685
# Epoch 268 | Temp: 0.0135 | Loss: 0.5827 | Accuracy: 0.7632
# Epoch 269 | Temp: 0.0134 | Loss: 0.5824 | Accuracy: 0.7628
# Epoch 270 | Temp: 0.0133 | Loss: 0.5765 | Accuracy: 0.7648
# Epoch 271 | Temp: 0.0131 | Loss: 0.6251 | Accuracy: 0.7364
# Epoch 272 | Temp: 0.0130 | Loss: 0.5845 | Accuracy: 0.7653
# Epoch 273 | Temp: 0.0129 | Loss: 0.5856 | Accuracy: 0.7638
# Epoch 274 | Temp: 0.0127 | Loss: 0.5938 | Accuracy: 0.7539
# Epoch 275 | Temp: 0.0126 | Loss: 0.5867 | Accuracy: 0.7555
# Epoch 276 | Temp: 0.0125 | Loss: 0.5861 | Accuracy: 0.7556
# Epoch 277 | Temp: 0.0124 | Loss: 0.5788 | Accuracy: 0.7646
# Epoch 278 | Temp: 0.0122 | Loss: 0.5822 | Accuracy: 0.7613
# Epoch 279 | Temp: 0.0121 | Loss: 0.5844 | Accuracy: 0.7572
# Epoch 280 | Temp: 0.0120 | Loss: 0.5757 | Accuracy: 0.7669
# Epoch 281 | Temp: 0.0119 | Loss: 0.5661 | Accuracy: 0.7664
# Epoch 282 | Temp: 0.0118 | Loss: 0.5722 | Accuracy: 0.7621
# Epoch 283 | Temp: 0.0116 | Loss: 0.5643 | Accuracy: 0.7688
# Epoch 284 | Temp: 0.0115 | Loss: 0.5701 | Accuracy: 0.7625
# Epoch 285 | Temp: 0.0114 | Loss: 0.5703 | Accuracy: 0.7594
# Epoch 286 | Temp: 0.0113 | Loss: 0.5525 | Accuracy: 0.7713
# Epoch 287 | Temp: 0.0112 | Loss: 0.5828 | Accuracy: 0.7538
# Epoch 288 | Temp: 0.0111 | Loss: 0.5729 | Accuracy: 0.7525
# Epoch 289 | Temp: 0.0110 | Loss: 0.5485 | Accuracy: 0.7784
# Epoch 290 | Temp: 0.0108 | Loss: 0.5561 | Accuracy: 0.7657
# Epoch 291 | Temp: 0.0107 | Loss: 0.5646 | Accuracy: 0.7622
# Epoch 292 | Temp: 0.0106 | Loss: 0.5643 | Accuracy: 0.7576
# Epoch 293 | Temp: 0.0105 | Loss: 0.5395 | Accuracy: 0.7796
# Epoch 294 | Temp: 0.0104 | Loss: 0.5588 | Accuracy: 0.7660
# Epoch 295 | Temp: 0.0103 | Loss: 0.5502 | Accuracy: 0.7659
# Epoch 296 | Temp: 0.0102 | Loss: 0.5590 | Accuracy: 0.7666
# Epoch 297 | Temp: 0.0101 | Loss: 0.5397 | Accuracy: 0.7756
# Epoch 298 | Temp: 0.0100 | Loss: 0.5612 | Accuracy: 0.7612
# Epoch 299 | Temp: 0.0100 | Loss: 0.5401 | Accuracy: 0.7707
# Epoch 300 | Temp: 0.0100 | Loss: 0.5310 | Accuracy: 0.7774
# Epoch 301 | Temp: 0.0100 | Loss: 0.5442 | Accuracy: 0.7669
# Epoch 302 | Temp: 0.0100 | Loss: 0.5283 | Accuracy: 0.7797
# Epoch 303 | Temp: 0.0100 | Loss: 0.5468 | Accuracy: 0.7692
# Epoch 304 | Temp: 0.0100 | Loss: 0.5248 | Accuracy: 0.7822
# Epoch 305 | Temp: 0.0100 | Loss: 0.5294 | Accuracy: 0.7803
# Epoch 306 | Temp: 0.0100 | Loss: 0.5409 | Accuracy: 0.7746
# Epoch 307 | Temp: 0.0100 | Loss: 0.5268 | Accuracy: 0.7838
# Epoch 308 | Temp: 0.0100 | Loss: 0.5367 | Accuracy: 0.7772
# Epoch 309 | Temp: 0.0100 | Loss: 0.5317 | Accuracy: 0.7781
# Epoch 310 | Temp: 0.0100 | Loss: 0.5355 | Accuracy: 0.7788
# Epoch 311 | Temp: 0.0100 | Loss: 0.6398 | Accuracy: 0.7191
# Epoch 312 | Temp: 0.0100 | Loss: 0.5095 | Accuracy: 0.7946
# Epoch 313 | Temp: 0.0100 | Loss: 0.5138 | Accuracy: 0.7930
# Epoch 314 | Temp: 0.0100 | Loss: 0.5350 | Accuracy: 0.7813
# Epoch 315 | Temp: 0.0100 | Loss: 0.5269 | Accuracy: 0.7868
# Epoch 316 | Temp: 0.0100 | Loss: 0.5239 | Accuracy: 0.7871
# Epoch 317 | Temp: 0.0100 | Loss: 0.5212 | Accuracy: 0.7883
# Epoch 318 | Temp: 0.0100 | Loss: 0.5202 | Accuracy: 0.7890
# Epoch 319 | Temp: 0.0100 | Loss: 0.5231 | Accuracy: 0.7880
# Epoch 320 | Temp: 0.0100 | Loss: 0.5274 | Accuracy: 0.7841
# Epoch 321 | Temp: 0.0100 | Loss: 0.5253 | Accuracy: 0.7839
# Epoch 322 | Temp: 0.0100 | Loss: 0.5135 | Accuracy: 0.7929
# Epoch 323 | Temp: 0.0100 | Loss: 0.5131 | Accuracy: 0.7915
# Epoch 324 | Temp: 0.0100 | Loss: 0.5295 | Accuracy: 0.7802
# Epoch 325 | Temp: 0.0100 | Loss: 0.5260 | Accuracy: 0.7840
# Epoch 326 | Temp: 0.0100 | Loss: 0.5224 | Accuracy: 0.7847
# Epoch 327 | Temp: 0.0100 | Loss: 0.5206 | Accuracy: 0.7842
# Epoch 328 | Temp: 0.0100 | Loss: 0.5146 | Accuracy: 0.7922
# Epoch 329 | Temp: 0.0100 | Loss: 0.5234 | Accuracy: 0.7802
# Epoch 330 | Temp: 0.0100 | Loss: 0.5242 | Accuracy: 0.7836
# Epoch 331 | Temp: 0.0100 | Loss: 0.5427 | Accuracy: 0.7694
# Epoch 332 | Temp: 0.0100 | Loss: 0.5523 | Accuracy: 0.7644
# Epoch 333 | Temp: 0.0100 | Loss: 0.5519 | Accuracy: 0.7681
# Epoch 334 | Temp: 0.0100 | Loss: 0.4960 | Accuracy: 0.8075
# Epoch 335 | Temp: 0.0100 | Loss: 0.5204 | Accuracy: 0.7859
# Epoch 336 | Temp: 0.0100 | Loss: 0.5245 | Accuracy: 0.7857
# Epoch 337 | Temp: 0.0100 | Loss: 0.5143 | Accuracy: 0.7942
# Epoch 338 | Temp: 0.0100 | Loss: 0.5190 | Accuracy: 0.7903
# Epoch 339 | Temp: 0.0100 | Loss: 0.5314 | Accuracy: 0.7834
# Epoch 340 | Temp: 0.0100 | Loss: 0.5148 | Accuracy: 0.7890
# Epoch 341 | Temp: 0.0100 | Loss: 0.5050 | Accuracy: 0.8005
# Epoch 342 | Temp: 0.0100 | Loss: 0.5311 | Accuracy: 0.7824
# Epoch 343 | Temp: 0.0100 | Loss: 0.5465 | Accuracy: 0.7668
# Epoch 344 | Temp: 0.0100 | Loss: 0.5114 | Accuracy: 0.7968
# Epoch 345 | Temp: 0.0100 | Loss: 0.6004 | Accuracy: 0.7426
# Epoch 346 | Temp: 0.0100 | Loss: 0.5381 | Accuracy: 0.7783
# Epoch 347 | Temp: 0.0100 | Loss: 0.5102 | Accuracy: 0.7978
# Epoch 348 | Temp: 0.0100 | Loss: 0.5064 | Accuracy: 0.7998
# Epoch 349 | Temp: 0.0100 | Loss: 0.5157 | Accuracy: 0.7911
# Epoch 350 | Temp: 0.0100 | Loss: 0.5195 | Accuracy: 0.7904
# Epoch 351 | Temp: 0.0100 | Loss: 0.5182 | Accuracy: 0.7860
# Epoch 352 | Temp: 0.0100 | Loss: 0.5151 | Accuracy: 0.7887
# Epoch 353 | Temp: 0.0100 | Loss: 0.5055 | Accuracy: 0.7984
# Epoch 354 | Temp: 0.0100 | Loss: 0.5151 | Accuracy: 0.7931
# Epoch 355 | Temp: 0.0100 | Loss: 0.5189 | Accuracy: 0.7905
# Epoch 356 | Temp: 0.0100 | Loss: 0.5167 | Accuracy: 0.7897
# Epoch 357 | Temp: 0.0100 | Loss: 0.5443 | Accuracy: 0.7691
# Epoch 358 | Temp: 0.0100 | Loss: 0.5586 | Accuracy: 0.7634
# Epoch 359 | Temp: 0.0100 | Loss: 0.5319 | Accuracy: 0.7798
# Epoch 360 | Temp: 0.0100 | Loss: 0.5094 | Accuracy: 0.7941
# Epoch 361 | Temp: 0.0100 | Loss: 0.5241 | Accuracy: 0.7877
# Epoch 362 | Temp: 0.0100 | Loss: 0.5207 | Accuracy: 0.7909
# Epoch 363 | Temp: 0.0100 | Loss: 0.5075 | Accuracy: 0.7965
# Epoch 364 | Temp: 0.0100 | Loss: 0.5236 | Accuracy: 0.7880
# Epoch 365 | Temp: 0.0100 | Loss: 0.5046 | Accuracy: 0.8027
# Epoch 366 | Temp: 0.0100 | Loss: 0.5230 | Accuracy: 0.7880
# Epoch 367 | Temp: 0.0100 | Loss: 0.5184 | Accuracy: 0.7889
# Epoch 368 | Temp: 0.0100 | Loss: 0.5076 | Accuracy: 0.7972
# Epoch 369 | Temp: 0.0100 | Loss: 0.4958 | Accuracy: 0.8053
# Epoch 370 | Temp: 0.0100 | Loss: 0.5210 | Accuracy: 0.7889
# Epoch 371 | Temp: 0.0100 | Loss: 0.5302 | Accuracy: 0.7797
# Epoch 372 | Temp: 0.0100 | Loss: 0.5330 | Accuracy: 0.7846
# Epoch 373 | Temp: 0.0100 | Loss: 0.5436 | Accuracy: 0.7691
# Epoch 374 | Temp: 0.0100 | Loss: 0.5163 | Accuracy: 0.7905
# Epoch 375 | Temp: 0.0100 | Loss: 0.5072 | Accuracy: 0.7986
# Epoch 376 | Temp: 0.0100 | Loss: 0.5197 | Accuracy: 0.7870
# Epoch 377 | Temp: 0.0100 | Loss: 0.5032 | Accuracy: 0.8032
# Epoch 378 | Temp: 0.0100 | Loss: 0.5052 | Accuracy: 0.7978
# Epoch 379 | Temp: 0.0100 | Loss: 0.4996 | Accuracy: 0.8010
# Epoch 380 | Temp: 0.0100 | Loss: 0.5163 | Accuracy: 0.7879
# Epoch 381 | Temp: 0.0100 | Loss: 0.5408 | Accuracy: 0.7719
# Epoch 382 | Temp: 0.0100 | Loss: 0.5233 | Accuracy: 0.7899
# Epoch 383 | Temp: 0.0100 | Loss: 0.5545 | Accuracy: 0.7632
# Epoch 384 | Temp: 0.0100 | Loss: 0.5050 | Accuracy: 0.8003
# Epoch 385 | Temp: 0.0100 | Loss: 0.5117 | Accuracy: 0.7938
# Epoch 386 | Temp: 0.0100 | Loss: 0.5020 | Accuracy: 0.8005
# Epoch 387 | Temp: 0.0100 | Loss: 0.5212 | Accuracy: 0.7885
# Epoch 388 | Temp: 0.0100 | Loss: 0.5243 | Accuracy: 0.7910
# Epoch 389 | Temp: 0.0100 | Loss: 0.4975 | Accuracy: 0.8025
# Epoch 390 | Temp: 0.0100 | Loss: 0.4978 | Accuracy: 0.8046
# Epoch 391 | Temp: 0.0100 | Loss: 0.5004 | Accuracy: 0.8036
# Epoch 392 | Temp: 0.0100 | Loss: 0.5114 | Accuracy: 0.7941
# Epoch 393 | Temp: 0.0100 | Loss: 0.5339 | Accuracy: 0.7753
# Epoch 394 | Temp: 0.0100 | Loss: 0.5172 | Accuracy: 0.7852
# Epoch 395 | Temp: 0.0100 | Loss: 0.5070 | Accuracy: 0.7995
# Epoch 396 | Temp: 0.0100 | Loss: 0.5223 | Accuracy: 0.7863
# Epoch 397 | Temp: 0.0100 | Loss: 0.5060 | Accuracy: 0.7965
# Epoch 398 | Temp: 0.0100 | Loss: 0.4886 | Accuracy: 0.8106
# Epoch 399 | Temp: 0.0100 | Loss: 0.4944 | Accuracy: 0.8079
# Epoch 400 | Temp: 0.0100 | Loss: 0.5001 | Accuracy: 0.8031
# Epoch 401 | Temp: 0.0100 | Loss: 0.5515 | Accuracy: 0.7646
# Epoch 402 | Temp: 0.0100 | Loss: 0.5094 | Accuracy: 0.7968
# Epoch 403 | Temp: 0.0100 | Loss: 0.5021 | Accuracy: 0.8036
# Epoch 404 | Temp: 0.0100 | Loss: 0.5078 | Accuracy: 0.7891
# Epoch 405 | Temp: 0.0100 | Loss: 0.5072 | Accuracy: 0.7958
# Epoch 406 | Temp: 0.0100 | Loss: 0.5262 | Accuracy: 0.7823
# Epoch 407 | Temp: 0.0100 | Loss: 0.4910 | Accuracy: 0.8083
# Epoch 408 | Temp: 0.0100 | Loss: 0.5129 | Accuracy: 0.7945
# Epoch 409 | Temp: 0.0100 | Loss: 0.4992 | Accuracy: 0.8020
# Epoch 410 | Temp: 0.0100 | Loss: 0.5273 | Accuracy: 0.7844
# Epoch 411 | Temp: 0.0100 | Loss: 0.5034 | Accuracy: 0.8025
# Epoch 412 | Temp: 0.0100 | Loss: 0.5095 | Accuracy: 0.7893
# Epoch 413 | Temp: 0.0100 | Loss: 0.5154 | Accuracy: 0.7900
# Epoch 414 | Temp: 0.0100 | Loss: 0.4938 | Accuracy: 0.8075
# Epoch 415 | Temp: 0.0100 | Loss: 0.5210 | Accuracy: 0.7903
# Epoch 416 | Temp: 0.0100 | Loss: 0.5040 | Accuracy: 0.7953
# Epoch 417 | Temp: 0.0100 | Loss: 0.4914 | Accuracy: 0.8079
# Epoch 418 | Temp: 0.0100 | Loss: 0.5017 | Accuracy: 0.8005
# Epoch 419 | Temp: 0.0100 | Loss: 0.5524 | Accuracy: 0.7622
# Epoch 420 | Temp: 0.0100 | Loss: 0.5237 | Accuracy: 0.7850
# Epoch 421 | Temp: 0.0100 | Loss: 0.5042 | Accuracy: 0.7986
# Epoch 422 | Temp: 0.0100 | Loss: 0.5143 | Accuracy: 0.7946
# Epoch 423 | Temp: 0.0100 | Loss: 0.5002 | Accuracy: 0.8011
# Epoch 424 | Temp: 0.0100 | Loss: 0.5006 | Accuracy: 0.8005
# Epoch 425 | Temp: 0.0100 | Loss: 0.5075 | Accuracy: 0.8016
# Epoch 426 | Temp: 0.0100 | Loss: 0.4932 | Accuracy: 0.8081
# Epoch 427 | Temp: 0.0100 | Loss: 0.5062 | Accuracy: 0.7972
# Epoch 428 | Temp: 0.0100 | Loss: 0.5270 | Accuracy: 0.7838
# Epoch 429 | Temp: 0.0100 | Loss: 0.4994 | Accuracy: 0.7993
# Epoch 430 | Temp: 0.0100 | Loss: 0.4976 | Accuracy: 0.8030
# Epoch 431 | Temp: 0.0100 | Loss: 0.4996 | Accuracy: 0.8055
# Epoch 432 | Temp: 0.0100 | Loss: 0.4952 | Accuracy: 0.8100
# Epoch 433 | Temp: 0.0100 | Loss: 0.4998 | Accuracy: 0.7987
# Epoch 434 | Temp: 0.0100 | Loss: 0.5300 | Accuracy: 0.7778
# Epoch 435 | Temp: 0.0100 | Loss: 0.5084 | Accuracy: 0.7921
# Epoch 436 | Temp: 0.0100 | Loss: 0.4926 | Accuracy: 0.8105
# Epoch 437 | Temp: 0.0100 | Loss: 0.4955 | Accuracy: 0.8062
# Epoch 438 | Temp: 0.0100 | Loss: 0.5158 | Accuracy: 0.7888
# Epoch 439 | Temp: 0.0100 | Loss: 0.4921 | Accuracy: 0.8075
# Epoch 440 | Temp: 0.0100 | Loss: 0.5067 | Accuracy: 0.7986
# Epoch 441 | Temp: 0.0100 | Loss: 0.5024 | Accuracy: 0.8020
# Epoch 442 | Temp: 0.0100 | Loss: 0.5435 | Accuracy: 0.7680
# Epoch 443 | Temp: 0.0100 | Loss: 0.5075 | Accuracy: 0.7976
# Epoch 444 | Temp: 0.0100 | Loss: 0.5049 | Accuracy: 0.8002
# Epoch 445 | Temp: 0.0100 | Loss: 0.4827 | Accuracy: 0.8091
# Epoch 446 | Temp: 0.0100 | Loss: 0.5201 | Accuracy: 0.7869
# Epoch 447 | Temp: 0.0100 | Loss: 0.5060 | Accuracy: 0.7974
# Epoch 448 | Temp: 0.0100 | Loss: 0.4859 | Accuracy: 0.8112
# Epoch 449 | Temp: 0.0100 | Loss: 0.5040 | Accuracy: 0.8041
# Epoch 450 | Temp: 0.0100 | Loss: 0.4997 | Accuracy: 0.8011
# Epoch 451 | Temp: 0.0100 | Loss: 0.4944 | Accuracy: 0.8068
# Epoch 452 | Temp: 0.0100 | Loss: 0.4996 | Accuracy: 0.8037
# Epoch 453 | Temp: 0.0100 | Loss: 0.4990 | Accuracy: 0.8054
# Epoch 454 | Temp: 0.0100 | Loss: 0.5066 | Accuracy: 0.7985
# Epoch 455 | Temp: 0.0100 | Loss: 0.4972 | Accuracy: 0.8048
# Epoch 456 | Temp: 0.0100 | Loss: 0.5044 | Accuracy: 0.8012
# Epoch 457 | Temp: 0.0100 | Loss: 0.5006 | Accuracy: 0.7999
# Epoch 458 | Temp: 0.0100 | Loss: 0.5133 | Accuracy: 0.7900
# Epoch 459 | Temp: 0.0100 | Loss: 0.5086 | Accuracy: 0.7929
# Epoch 460 | Temp: 0.0100 | Loss: 0.4970 | Accuracy: 0.8037
# Epoch 461 | Temp: 0.0100 | Loss: 0.5040 | Accuracy: 0.7970
# Epoch 462 | Temp: 0.0100 | Loss: 0.5010 | Accuracy: 0.7994
# Epoch 463 | Temp: 0.0100 | Loss: 0.4936 | Accuracy: 0.8093
# Epoch 464 | Temp: 0.0100 | Loss: 0.4841 | Accuracy: 0.8190
# Epoch 465 | Temp: 0.0100 | Loss: 0.4892 | Accuracy: 0.8134
# Epoch 466 | Temp: 0.0100 | Loss: 0.5155 | Accuracy: 0.7900
# Epoch 467 | Temp: 0.0100 | Loss: 0.5039 | Accuracy: 0.7982
# Epoch 468 | Temp: 0.0100 | Loss: 0.5140 | Accuracy: 0.7945
# Epoch 469 | Temp: 0.0100 | Loss: 0.4862 | Accuracy: 0.8145
# Epoch 470 | Temp: 0.0100 | Loss: 0.4956 | Accuracy: 0.7993
# Epoch 471 | Temp: 0.0100 | Loss: 0.5109 | Accuracy: 0.7919
# Epoch 472 | Temp: 0.0100 | Loss: 0.4847 | Accuracy: 0.8146
# Epoch 473 | Temp: 0.0100 | Loss: 0.4972 | Accuracy: 0.8056
# Epoch 474 | Temp: 0.0100 | Loss: 0.5033 | Accuracy: 0.7991
# Epoch 475 | Temp: 0.0100 | Loss: 0.5083 | Accuracy: 0.7949
# Epoch 476 | Temp: 0.0100 | Loss: 0.5063 | Accuracy: 0.7964
# Epoch 477 | Temp: 0.0100 | Loss: 0.5389 | Accuracy: 0.7765
# Epoch 478 | Temp: 0.0100 | Loss: 0.4865 | Accuracy: 0.8126
# Epoch 479 | Temp: 0.0100 | Loss: 0.5053 | Accuracy: 0.7991
# Epoch 480 | Temp: 0.0100 | Loss: 0.4918 | Accuracy: 0.8035
# Epoch 481 | Temp: 0.0100 | Loss: 0.4944 | Accuracy: 0.8052
# Epoch 482 | Temp: 0.0100 | Loss: 0.5142 | Accuracy: 0.7919
# Epoch 483 | Temp: 0.0100 | Loss: 0.5193 | Accuracy: 0.7886
# Epoch 484 | Temp: 0.0100 | Loss: 0.4793 | Accuracy: 0.8165
# Epoch 485 | Temp: 0.0100 | Loss: 0.4920 | Accuracy: 0.8111
# Epoch 486 | Temp: 0.0100 | Loss: 0.4953 | Accuracy: 0.8007
# Epoch 487 | Temp: 0.0100 | Loss: 0.4957 | Accuracy: 0.8078
# Epoch 488 | Temp: 0.0100 | Loss: 0.4886 | Accuracy: 0.8107
# Epoch 489 | Temp: 0.0100 | Loss: 0.4959 | Accuracy: 0.8043
# Epoch 490 | Temp: 0.0100 | Loss: 0.4816 | Accuracy: 0.8178
# Epoch 491 | Temp: 0.0100 | Loss: 0.4996 | Accuracy: 0.8049
# Epoch 492 | Temp: 0.0100 | Loss: 0.4963 | Accuracy: 0.8058
# Epoch 493 | Temp: 0.0100 | Loss: 0.4998 | Accuracy: 0.7994
# Epoch 494 | Temp: 0.0100 | Loss: 0.4771 | Accuracy: 0.8171
# Epoch 495 | Temp: 0.0100 | Loss: 0.4868 | Accuracy: 0.8084
# Epoch 496 | Temp: 0.0100 | Loss: 0.4901 | Accuracy: 0.8095
# Epoch 497 | Temp: 0.0100 | Loss: 0.4772 | Accuracy: 0.8194
# Epoch 498 | Temp: 0.0100 | Loss: 0.5070 | Accuracy: 0.7940
# Epoch 499 | Temp: 0.0100 | Loss: 0.5038 | Accuracy: 0.7949
# Epoch 500 | Temp: 0.0100 | Loss: 0.4937 | Accuracy: 0.8064
